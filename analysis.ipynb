# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("MOE kenyan schools.csv")
df
# Out:
#                                       Name     PROVINCE      DISTRICT  \
# 0      2005 MUNICIPALITY MARIAKANI NUR SCH  RIFT VALLEY      LAIKIPIA
# 1      2005 MUNICIPALITY MARIAKANI PRI SCH  RIFT VALLEY      LAIKIPIA
# 2                    39 BRIDGE ACADEMY NUR      EASTERN      MACHAKOS
# 3                     39 BRIGE ACADEMY PRI      EASTERN      MACHAKOS
# 4                    3-WAY ACADEMY PRI SCH  RIFT VALLEY        NAKURU
# ...                                    ...          ...           ...
# 72014                        ZSTRA ACADEMY      NAIROBI       NAIROBI
# 72015                           ZULULU ECD      WESTERN        VIHIGA
# 72016                       ZULULU PRY SCH      WESTERN        VIHIGA
# 72017                  ZUNGULUKANI NURSERY        COAST  TAITA TAVETA
# 72018                  ZUNGULUKANI PRIMARY        COAST  TAITA TAVETA
#
#          COSTITUENCY     DIVISION      LOCATION           SUBLOCATIO  \
# ...

# %%
df["Sponsor"].value_counts()
# Out:
# RELIGIOUS ORGANIZATION                     26101
# COMMUNITY                                  13886
# CENTRAL GOVERNMENT/DEB                     12435
# PRIVATE INDIVIDUAL                         11391
# LOCAL GOVERNMENT AUTHORITY                  1716
# PRIVATE INDIVIDUAL/ORGANIZATION             1529
# NGO/CBO                                      844
# RELIGIOUS ORGANISATION                       535
# PRIVATE INDIVIDUAL/ORGANISATION              358
# LOCAL AUTHORITY                               10
# LOCAL GORVERNMENT AUTHORITY                   10
# PARENTS                                        8
# M                                              8
# O                                              2
# MOI UNIVERSITY                                 2
# KIPKEINO CHILDREN HOME                         2
# SELF HELP GROUP                                2
# MINISTRY OF DEFENCE                            2
# REE                                            2
# ...

# %%
row_drop=["PARENTS","M","O","MOI UNIVERSITY","KIPKEINO CHILDREN HOME","SELF HELP GROUP","MINISTRY OF DEFENCE","REE","DIRECTOR","UON","OTHER","NOT APPLICABLE","COUNTRY COUNCIL","LEWA ED TRUST","MIN OF GENDER/SOCIAL SERVICES","KENYAN NAVY","ESTATE-KIRIMARA","SSK NETHERLAND"]
mask=df["Sponsor"].isin(row_drop)

df=df[~mask]
df
# Out:
#                                       Name     PROVINCE      DISTRICT  \
# 0      2005 MUNICIPALITY MARIAKANI NUR SCH  RIFT VALLEY      LAIKIPIA
# 1      2005 MUNICIPALITY MARIAKANI PRI SCH  RIFT VALLEY      LAIKIPIA
# 2                    39 BRIDGE ACADEMY NUR      EASTERN      MACHAKOS
# 3                     39 BRIGE ACADEMY PRI      EASTERN      MACHAKOS
# 4                    3-WAY ACADEMY PRI SCH  RIFT VALLEY        NAKURU
# ...                                    ...          ...           ...
# 72014                        ZSTRA ACADEMY      NAIROBI       NAIROBI
# 72015                           ZULULU ECD      WESTERN        VIHIGA
# 72016                       ZULULU PRY SCH      WESTERN        VIHIGA
# 72017                  ZUNGULUKANI NURSERY        COAST  TAITA TAVETA
# 72018                  ZUNGULUKANI PRIMARY        COAST  TAITA TAVETA
#
#          COSTITUENCY     DIVISION      LOCATION           SUBLOCATIO  \
# ...

# %%
df["Sponsor"].value_counts()
# Out:
# RELIGIOUS ORGANIZATION                     26101
# COMMUNITY                                  13886
# CENTRAL GOVERNMENT/DEB                     12435
# PRIVATE INDIVIDUAL                         11391
# LOCAL GOVERNMENT AUTHORITY                  1716
# PRIVATE INDIVIDUAL/ORGANIZATION             1529
# NGO/CBO                                      844
# RELIGIOUS ORGANISATION                       535
# PRIVATE INDIVIDUAL/ORGANISATION              358
# LOCAL GORVERNMENT AUTHORITY                   10
# LOCAL AUTHORITY                               10
# NGO/CBO(Plan Interntnl)                        1
# MIN.GENDER, SPORTS, CULTURE                    1
# RCO                                            1
# OTHER, MINISTRY OF STATE YOUTH AFFAIRS         1
# PTA                                            1
# FATHER GROLL'S WELFAE PROJECT                  1
# PUBLIC                                         1
# KENYA NAVY                                     1
# ...

# %%
row_drop_2=["NGO/CBO(Plan Interntnl)","MIN.GENDER, SPORTS ,CULTURE","RCO","OTHER,MINISTRY OF STATE YOUTH AFFAIRS","PTA","FATHER GROLL'S WELFAE PROJECT","PUBLIC","KENYA NAVY","OTHER, MINISTRY OF YOUTH AFFAIRS","LL","ESTATE-KIRIMARA FARM","ESTATE","DOD","DEB","NON -PROFIT MISSION UNDER SOCIETY ACT","NON-PROFIT MISSION UNDER SOCIETY ACT","PRIVATE INDIVIDUAL/PRIVATE ORGANIZATION"]
mask=df["Sponsor"].isin(row_drop_2)

df=df[~mask]
df
# Out:
#                                       Name     PROVINCE      DISTRICT  \
# 0      2005 MUNICIPALITY MARIAKANI NUR SCH  RIFT VALLEY      LAIKIPIA
# 1      2005 MUNICIPALITY MARIAKANI PRI SCH  RIFT VALLEY      LAIKIPIA
# 2                    39 BRIDGE ACADEMY NUR      EASTERN      MACHAKOS
# 3                     39 BRIGE ACADEMY PRI      EASTERN      MACHAKOS
# 4                    3-WAY ACADEMY PRI SCH  RIFT VALLEY        NAKURU
# ...                                    ...          ...           ...
# 72014                        ZSTRA ACADEMY      NAIROBI       NAIROBI
# 72015                           ZULULU ECD      WESTERN        VIHIGA
# 72016                       ZULULU PRY SCH      WESTERN        VIHIGA
# 72017                  ZUNGULUKANI NURSERY        COAST  TAITA TAVETA
# 72018                  ZUNGULUKANI PRIMARY        COAST  TAITA TAVETA
#
#          COSTITUENCY     DIVISION      LOCATION           SUBLOCATIO  \
# ...

# %%
df["Sponsor"].value_counts()
# Out:
# RELIGIOUS ORGANIZATION                    26101
# COMMUNITY                                 13886
# CENTRAL GOVERNMENT/DEB                    12435
# PRIVATE INDIVIDUAL                        11391
# LOCAL GOVERNMENT AUTHORITY                 1716
# PRIVATE INDIVIDUAL/ORGANIZATION            1529
# NGO/CBO                                     844
# RELIGIOUS ORGANISATION                      535
# PRIVATE INDIVIDUAL/ORGANISATION             358
# LOCAL AUTHORITY                              10
# LOCAL GORVERNMENT AUTHORITY                  10
# OTTHER, POLICE                                1
# OTHER, MINISTRY OF STATE YOUTH AFFAIRS        1
# MIN.GENDER, SPORTS, CULTURE                   1
# KAGANDA PARENTS                               1
# CI                                            1
# COP                                           1
# GK PRISON ELDORET                             1
# E                                             1
# NONE                                          1
# ...

# %%
row_drop_3=["OTHER, POLICE","OTHER, MINISTRY OF STATE YOUTH AFFAIRS","MIN.GENDER, SPORTS, CULTURE","KAGANDA PARENTS","CI","COP","GK PRISON ELDORERT","E"]
mask=df["Sponsor"].isin(row_drop_3)

df=df[~mask]
df
# Out:
#                                       Name     PROVINCE      DISTRICT  \
# 0      2005 MUNICIPALITY MARIAKANI NUR SCH  RIFT VALLEY      LAIKIPIA
# 1      2005 MUNICIPALITY MARIAKANI PRI SCH  RIFT VALLEY      LAIKIPIA
# 2                    39 BRIDGE ACADEMY NUR      EASTERN      MACHAKOS
# 3                     39 BRIGE ACADEMY PRI      EASTERN      MACHAKOS
# 4                    3-WAY ACADEMY PRI SCH  RIFT VALLEY        NAKURU
# ...                                    ...          ...           ...
# 72014                        ZSTRA ACADEMY      NAIROBI       NAIROBI
# 72015                           ZULULU ECD      WESTERN        VIHIGA
# 72016                       ZULULU PRY SCH      WESTERN        VIHIGA
# 72017                  ZUNGULUKANI NURSERY        COAST  TAITA TAVETA
# 72018                  ZUNGULUKANI PRIMARY        COAST  TAITA TAVETA
#
#          COSTITUENCY     DIVISION      LOCATION           SUBLOCATIO  \
# ...

# %%
df["Sponsor"].value_counts()
# Out:
# RELIGIOUS ORGANIZATION             26101
# COMMUNITY                          13886
# CENTRAL GOVERNMENT/DEB             12435
# PRIVATE INDIVIDUAL                 11391
# LOCAL GOVERNMENT AUTHORITY          1716
# PRIVATE INDIVIDUAL/ORGANIZATION     1529
# NGO/CBO                              844
# RELIGIOUS ORGANISATION               535
# PRIVATE INDIVIDUAL/ORGANISATION      358
# LOCAL AUTHORITY                       10
# LOCAL GORVERNMENT AUTHORITY           10
# GK PRISON ELDORET                      1
# OTTHER, POLICE                         1
# NONE                                   1
# Name: Sponsor, dtype: int64

# %%
row_drop_4=["GK PRISON ELDORET","OTHER, POLICE","NONE"]
mask=df["Sponsor"].isin(row_drop_4)

df=df[~mask]
df
# Out:
#                                       Name     PROVINCE      DISTRICT  \
# 0      2005 MUNICIPALITY MARIAKANI NUR SCH  RIFT VALLEY      LAIKIPIA
# 1      2005 MUNICIPALITY MARIAKANI PRI SCH  RIFT VALLEY      LAIKIPIA
# 2                    39 BRIDGE ACADEMY NUR      EASTERN      MACHAKOS
# 3                     39 BRIGE ACADEMY PRI      EASTERN      MACHAKOS
# 4                    3-WAY ACADEMY PRI SCH  RIFT VALLEY        NAKURU
# ...                                    ...          ...           ...
# 72014                        ZSTRA ACADEMY      NAIROBI       NAIROBI
# 72015                           ZULULU ECD      WESTERN        VIHIGA
# 72016                       ZULULU PRY SCH      WESTERN        VIHIGA
# 72017                  ZUNGULUKANI NURSERY        COAST  TAITA TAVETA
# 72018                  ZUNGULUKANI PRIMARY        COAST  TAITA TAVETA
#
#          COSTITUENCY     DIVISION      LOCATION           SUBLOCATIO  \
# ...

# %%
df["Sponsor"].value_counts()
# Out:
# RELIGIOUS ORGANIZATION             26101
# COMMUNITY                          13886
# CENTRAL GOVERNMENT/DEB             12435
# PRIVATE INDIVIDUAL                 11391
# LOCAL GOVERNMENT AUTHORITY          1716
# PRIVATE INDIVIDUAL/ORGANIZATION     1529
# NGO/CBO                              844
# RELIGIOUS ORGANISATION               535
# PRIVATE INDIVIDUAL/ORGANISATION      358
# LOCAL AUTHORITY                       10
# LOCAL GORVERNMENT AUTHORITY           10
# OTTHER, POLICE                         1
# Name: Sponsor, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 71957 entries, 0 to 72018
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          71957 non-null  object
#  1   PROVINCE      71957 non-null  object
#  2   DISTRICT      71957 non-null  object
#  3   COSTITUENCY   69324 non-null  object
#  4   DIVISION      71954 non-null  object
#  5   LOCATION      71955 non-null  object
#  6   SUBLOCATIO    71953 non-null  object
#  7   Level         71285 non-null  object
#  8   Status        69632 non-null  object
#  9   Sponsor       68816 non-null  object
#  10  Longitude     71957 non-null  float64
#  11  Latitude      71957 non-null  float64
#  12  # Classrooms  50661 non-null  float64
# dtypes: float64(3), object(10)
# memory usage: 7.7+ MB

# %%
df.drop(["COSTITUENCY", "DIVISION", "LOCATION", "SUBLOCATIO","# Classrooms"], axis=1, inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_7296\742569898.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(["COSTITUENCY", "DIVISION", "LOCATION", "SUBLOCATIO","# Classrooms"], axis=1, inplace=True)

# %%
df
# Out:
#                                       Name     PROVINCE      DISTRICT  \
# 0      2005 MUNICIPALITY MARIAKANI NUR SCH  RIFT VALLEY      LAIKIPIA
# 1      2005 MUNICIPALITY MARIAKANI PRI SCH  RIFT VALLEY      LAIKIPIA
# 2                    39 BRIDGE ACADEMY NUR      EASTERN      MACHAKOS
# 3                     39 BRIGE ACADEMY PRI      EASTERN      MACHAKOS
# 4                    3-WAY ACADEMY PRI SCH  RIFT VALLEY        NAKURU
# ...                                    ...          ...           ...
# 72014                        ZSTRA ACADEMY      NAIROBI       NAIROBI
# 72015                           ZULULU ECD      WESTERN        VIHIGA
# 72016                       ZULULU PRY SCH      WESTERN        VIHIGA
# 72017                  ZUNGULUKANI NURSERY        COAST  TAITA TAVETA
# 72018                  ZUNGULUKANI PRIMARY        COAST  TAITA TAVETA
#
#                         Level   Status                     Sponsor  Longitude  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 71957 entries, 0 to 72018
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       71957 non-null  object
#  1   PROVINCE   71957 non-null  object
#  2   DISTRICT   71957 non-null  object
#  3   Level      71285 non-null  object
#  4   Status     69632 non-null  object
#  5   Sponsor    68816 non-null  object
#  6   Longitude  71957 non-null  float64
#  7   Latitude   71957 non-null  float64
# dtypes: float64(2), object(6)
# memory usage: 4.9+ MB

# %%
mode_level=df["Level"].mode().iloc[0]
mode_level
# Out:
# 'ECD/PRE-PRIMARY SCHOOL'

# %%
df["Level"].fillna(mode_level,inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_7296\2574784986.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Level"].fillna(mode_level,inplace=True)

# %%
mode_status=df["Status"].mode().iloc[0]
mode_status
# Out:
# 'PUBLIC'

# %%
df["Status"].fillna(mode_status,inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_7296\2778846554.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Status"].fillna(mode_status,inplace=True)

# %%
mode_sponsor=df["Sponsor"].mode().iloc[0]
mode_sponsor
# Out:
# 'RELIGIOUS ORGANIZATION'

# %%
df["Sponsor"].fillna(mode_sponsor,inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_7296\2420983493.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sponsor"].fillna(mode_sponsor,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 71957 entries, 0 to 72018
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       71957 non-null  object
#  1   PROVINCE   71957 non-null  object
#  2   DISTRICT   71957 non-null  object
#  3   Level      71957 non-null  object
#  4   Status     71957 non-null  object
#  5   Sponsor    71957 non-null  object
#  6   Longitude  71957 non-null  float64
#  7   Latitude   71957 non-null  float64
# dtypes: float64(2), object(6)
# memory usage: 4.9+ MB

# %%
df["Province_1"]=df["PROVINCE"].astype("category").cat.codes
df["District_1"]=df["DISTRICT"].astype("category").cat.codes
df["level_1"]=df["Level"].astype("category").cat.codes
df["status_1"]=df["Status"].astype("category").cat.codes
df["sponsor_1"]=df["Sponsor"].astype("category").cat.codes
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_7296\3902776673.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Province_1"]=df["PROVINCE"].astype("category").cat.codes
# C:\Users\DELL\AppData\Local\Temp\ipykernel_7296\3902776673.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["District_1"]=df["DISTRICT"].astype("category").cat.codes
# C:\Users\DELL\AppData\Local\Temp\ipykernel_7296\3902776673.py:3: SettingWithCopyWarning:
# ...

# %%
df
# Out:
#                                       Name     PROVINCE      DISTRICT  \
# 0      2005 MUNICIPALITY MARIAKANI NUR SCH  RIFT VALLEY      LAIKIPIA
# 1      2005 MUNICIPALITY MARIAKANI PRI SCH  RIFT VALLEY      LAIKIPIA
# 2                    39 BRIDGE ACADEMY NUR      EASTERN      MACHAKOS
# 3                     39 BRIGE ACADEMY PRI      EASTERN      MACHAKOS
# 4                    3-WAY ACADEMY PRI SCH  RIFT VALLEY        NAKURU
# ...                                    ...          ...           ...
# 72014                        ZSTRA ACADEMY      NAIROBI       NAIROBI
# 72015                           ZULULU ECD      WESTERN        VIHIGA
# 72016                       ZULULU PRY SCH      WESTERN        VIHIGA
# 72017                  ZUNGULUKANI NURSERY        COAST  TAITA TAVETA
# 72018                  ZUNGULUKANI PRIMARY        COAST  TAITA TAVETA
#
#                         Level   Status                     Sponsor  Longitude  \
# ...

# %%
df.head(20)
# Out:
#                                       Name       PROVINCE  \
# 0      2005 MUNICIPALITY MARIAKANI NUR SCH    RIFT VALLEY
# 1      2005 MUNICIPALITY MARIAKANI PRI SCH    RIFT VALLEY
# 2                    39 BRIDGE ACADEMY NUR        EASTERN
# 3                     39 BRIGE ACADEMY PRI        EASTERN
# 4                    3-WAY ACADEMY PRI SCH    RIFT VALLEY
# 5                                3-WAY ECD    RIFT VALLEY
# 6                               64 SEC SCH    RIFT VALLEY
# 7                              7 FOLKS PRI        EASTERN
# 8                            A C C & S ECD  NORTH EASTERN
# 9                        A C C & S PRIMARY  NORTH EASTERN
# 10                               A D C ECD  NORTH EASTERN
# 11          A HAPPY OFFER CHILDRENS CENTER        NAIROBI
# 12      A HAPPY OFFER CHILDRENS CENTER ECD        NAIROBI
# 13               A I C OLENGURUONE NURSERY    RIFT VALLEY
# 14               A RAY OF HOPE ACADEMY ECD          COAST
# ...

# %%
df.tail(20)
# Out:
#                               Name     PROVINCE              DISTRICT  \
# 71999              ZIWANI PRI  SCH        COAST                 KWALE
# 72000               ZIWANI PRI SCH        COAST                  LAMU
# 72001               ZIWANI PRIMARY        COAST          TAITA TAVETA
# 72002               ZIWANI PRIMARY        COAST            TANA RIVER
# 72003  ZIWANI SCH FOR THE DEAF ECD        COAST  MOMBASA MUNICIPALITY
# 72004  ZIWANI SCH FOR THE DEAF PRY        COAST  MOMBASA MUNICIPALITY
# 72005           ZOCHIN ACADEMY ECD  RIFT VALLEY           UASIN GISHU
# 72006       ZOCHIN ACADEMY PRI SCH  RIFT VALLEY           UASIN GISHU
# 72007                ZOMBE NUR SCH      EASTERN                 KITUI
# 72008                ZOMBE PRI SCH      EASTERN                 KITUI
# 72009      ZOMBE YOUTH POLYTECHNIC      EASTERN                 KITUI
# 72010          ZOOM JUNIOR ACADEMY      EASTERN              MACHAKOS
# ...

# %%
df.to_csv("MOE clean data")

# %%
df["Sponsor"].value_counts()
# Out:
# RELIGIOUS ORGANIZATION             29242
# COMMUNITY                          13886
# CENTRAL GOVERNMENT/DEB             12435
# PRIVATE INDIVIDUAL                 11391
# LOCAL GOVERNMENT AUTHORITY          1716
# PRIVATE INDIVIDUAL/ORGANIZATION     1529
# NGO/CBO                              844
# RELIGIOUS ORGANISATION               535
# PRIVATE INDIVIDUAL/ORGANISATION      358
# LOCAL AUTHORITY                       10
# LOCAL GORVERNMENT AUTHORITY           10
# OTTHER, POLICE                         1
# Name: Sponsor, dtype: int64

# %%
df1=pd.read_csv("locations.csv")
df1
# Out:
#        Longitude  Latitude
# 0       36.34676   0.05122
# 1       36.34676   0.05122
# 2       36.97636  -1.44281
# 3       36.97636  -1.44281
# 4       35.71360  -0.23212
# ...          ...       ...
# 72014   36.90237  -1.30505
# 72015   34.73243   0.00410
# 72016   34.73243   0.00410
# 72017   38.92489  -3.95005
# 72018   38.92653  -3.95128
#
# [72019 rows x 2 columns]

# %%
df1.to_json("locations.json")
